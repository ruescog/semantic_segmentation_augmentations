# %%
from StatisticalAnalysis import statisticalComparison

# %%
statisticalComparison("SSA_testing.csv")
# Out:
# SSA_testing.csv
# ['Vanilla' 'COR-1-100' 'COR-1-200' 'COR-1-300' 'COR-2-100' 'COR-2-200'
#  'COR-2-300' 'COR-3-100' 'COR-3-200' 'COR-3-300' 'COS-1-150-B'
#  'COS-1-150-A' 'COS-1-250-B' 'COS-1-250-A' 'COS-2-150-B' 'COS-2-150-A'
#  'COS-2-250-B' 'COS-2-250-A' 'COHS-.05-25' 'COHS-.05-50' 'COHS-.05-200'
#  'COHS-.15-25' 'COHS-.15-50' 'COHS-.15-200' 'COHS-.25-25' 'COHS-.25-50'
#  'COHS-.25-200' 'CMR-1-100' 'CMR-1-200' 'CMR-1-300' 'CMR-2-100'
#  'CMR-2-200' 'CMR-2-300' 'CMS-1-150-B' 'CMS-1-150-A' 'CMS-1-250-B'
#  'CMS-1-250-A' 'CMS-2-150-B' 'CMS-2-150-A' 'CMS-2-250-B' 'CMS-2-250-A'
#  'CutMixRICAP' 'CMRS-1-150-B' 'CMRS-1-150-A' 'CMRS-1-250-B' 'CMRS-1-250-A'
#  'CMRS-2-150-B' 'CMRS-2-150-A' 'CMRS-2-250-B' 'CMRS-2-250-A']
# ...
# Report
# ...
# **********************************************************
# Mean and std
# **********************************************************
# Vanilla: 0.792896 (0.026170)
# COR-1-100: 0.794297 (0.032114)
# COR-1-200: 0.783401 (0.025661)
# ...
