# %%
from StatisticalAnalysis import statisticalComparison
import pandas as pd

# %%
df = pd.read_csv("SSA_testing.csv")
df["Model"] = df["Model"].apply(lambda e: e.replace(" ", ""))
df.to_csv("SSA_testing.csv", index = False)

# %%
statisticalComparison("SSA_testing.csv")
# Out:
# SSA_testing.csv
# ['Vanilla' 'COR1(100,100)' 'COR1(200,200)' 'COR1(300,300)' 'COR2(100,100)'
#  'COR2(200,200)' 'COR2(300,300)' 'COR3(100,100)' 'COR3(200,200)'
#  'COR3(300,300)' 'COS1(150,150)HoleMakerBounded'
#  'COS1(150,150)HoleMakerAttention' 'COS1(250,250)HoleMakerBounded'
#  'COS1(250,250)HoleMakerAttention' 'COS2(150,150)HoleMakerBounded'
#  'COS2(150,150)HoleMakerAttention' 'COS2(250,250)HoleMakerBounded'
#  'COS2(250,250)HoleMakerAttention' 'COHS0.05(25,25)' 'COHS0.05(50,50)'
#  'COHS0.05(200,200)' 'COHS0.15(25,25)' 'COHS0.15(50,50)'
#  'COHS0.15(200,200)' 'COHS0.25(25,25)' 'COHS0.25(50,50)'
#  'COHS0.25(200,200)' 'CMR1(100,100)' 'CMR1(200,200)' 'CMR1(300,300)'
#  'CMR2(100,100)' 'CMR2(200,200)' 'CMR2(300,300)' 'CMRmod1(100,100)'
#  'CMRmod1(200,200)' 'CMRmod1(300,300)' 'CMRmod2(100,100)'
#  'CMRmod2(200,200)' 'CMRmod2(300,300)' 'CMS1(150,150)HoleMakerBounded'
#  'CMS1(150,150)HoleMakerAttention' 'CMS1(250,250)HoleMakerBounded'
#  'CMS1(250,250)HoleMakerAttention' 'CMS2(150,150)HoleMakerBounded'
#  'CMS2(150,150)HoleMakerAttention' 'CMS2(250,250)HoleMakerBounded'
#  'CMS2(250,250)HoleMakerAttention' 'CMRICAP0None' 'CMRICAP0.2None'
#  'CMRICAP0.4None' 'CMRICAPNone0.2' 'CMRICAPNone0.4'
#  'CMRM1(150,150)HoleMakerBounded' 'CMRM1(150,150)HoleMakerAttention'
#  'CMRM1(250,250)HoleMakerBounded' 'CMRM1(250,250)HoleMakerAttention'
#  'CMRM2(150,150)HoleMakerBounded' 'CMRM2(150,150)HoleMakerAttention'
#  'CMRM2(250,250)HoleMakerBounded' 'CMRM2(250,250)HoleMakerAttention'
#  'CM11True' 'CM11False' 'CM1-1True' 'CM1-1False' 'CM31True' 'CM31False'
#  'CM3-1True' 'CM3-1False' 'CM51True' 'CM51False' 'CM5-1True' 'CM5-1False'
#  'ALL']
# ==========================================================
# Report
# ==========================================================
# **********************************************************
# Mean and std
# **********************************************************
# Vanilla: 0.827460 (0.035571)
# COR1(100,100): 0.841202 (0.013736)
# COR1(200,200): 0.821129 (0.012375)
# COR1(300,300): 0.773209 (0.084583)
# COR2(100,100): 0.817134 (0.042455)
# COR2(200,200): 0.831467 (0.007767)
# COR2(300,300): 0.818005 (0.021454)
# COR3(100,100): 0.808973 (0.060968)
# COR3(200,200): 0.789099 (0.057262)
# COR3(300,300): 0.810352 (0.023225)
# COS1(150,150)HoleMakerBounded: 0.857317 (0.007808)
# COS1(150,150)HoleMakerAttention: 0.836305 (0.027594)
# COS1(250,250)HoleMakerBounded: 0.824201 (0.027790)
# COS1(250,250)HoleMakerAttention: 0.826463 (0.040882)
# COS2(150,150)HoleMakerBounded: 0.822420 (0.050554)
# COS2(150,150)HoleMakerAttention: 0.828123 (0.025013)
# COS2(250,250)HoleMakerBounded: 0.832013 (0.026281)
# COS2(250,250)HoleMakerAttention: 0.835955 (0.026536)
# COHS0.05(25,25): 0.822032 (0.026868)
# COHS0.05(50,50): 0.815578 (0.048527)
# COHS0.05(200,200): 0.840124 (0.024733)
# COHS0.15(25,25): 0.828040 (0.031015)
# COHS0.15(50,50): 0.822200 (0.044631)
# COHS0.15(200,200): 0.833286 (0.042220)
# COHS0.25(25,25): 0.750483 (0.121156)
# COHS0.25(50,50): 0.792421 (0.042245)
# COHS0.25(200,200): 0.821040 (0.027817)
# CMR1(100,100): 0.831088 (0.026053)
# CMR1(200,200): 0.846817 (0.022246)
# CMR1(300,300): 0.832218 (0.032848)
# CMR2(100,100): 0.811097 (0.028332)
# CMR2(200,200): 0.819828 (0.043649)
# CMR2(300,300): 0.800869 (0.049532)
# CMRmod1(100,100): 0.811443 (0.013967)
# CMRmod1(200,200): 0.825552 (0.024318)
# CMRmod1(300,300): 0.786993 (0.025543)
# CMRmod2(100,100): 0.791797 (0.034226)
# CMRmod2(200,200): 0.780006 (0.049779)
# CMRmod2(300,300): 0.821298 (0.031336)
# CMS1(150,150)HoleMakerBounded: 0.836111 (0.037246)
# CMS1(150,150)HoleMakerAttention: 0.839674 (0.033373)
# CMS1(250,250)HoleMakerBounded: 0.816867 (0.022683)
# CMS1(250,250)HoleMakerAttention: 0.817381 (0.030368)
# CMS2(150,150)HoleMakerBounded: 0.837327 (0.044765)
# CMS2(150,150)HoleMakerAttention: 0.833316 (0.025474)
# CMS2(250,250)HoleMakerBounded: 0.849804 (0.013788)
# CMS2(250,250)HoleMakerAttention: 0.829441 (0.024736)
# CMRICAP0None: 0.819364 (0.025707)
# CMRICAP0.2None: 0.839994 (0.022291)
# CMRICAP0.4None: 0.814543 (0.030310)
# CMRICAPNone0.2: 0.826493 (0.024364)
# CMRICAPNone0.4: 0.805068 (0.042317)
# CMRM1(150,150)HoleMakerBounded: 0.815463 (0.012725)
# CMRM1(150,150)HoleMakerAttention: 0.801178 (0.041662)
# CMRM1(250,250)HoleMakerBounded: 0.805663 (0.030747)
# CMRM1(250,250)HoleMakerAttention: 0.817611 (0.020678)
# CMRM2(150,150)HoleMakerBounded: 0.809835 (0.034993)
# CMRM2(150,150)HoleMakerAttention: 0.823677 (0.019673)
# CMRM2(250,250)HoleMakerBounded: 0.783133 (0.048427)
# CMRM2(250,250)HoleMakerAttention: 0.768397 (0.043711)
# CM11True: 0.836837 (0.026745)
# CM11False: 0.817852 (0.033317)
# CM1-1True: 0.834465 (0.016173)
# CM1-1False: 0.821834 (0.092508)
# CM31True: 0.838461 (0.033713)
# CM31False: 0.831131 (0.033238)
# CM3-1True: 0.801477 (0.058667)
# CM3-1False: 0.798294 (0.046487)
# CM51True: 0.830115 (0.035837)
# CM51False: 0.825219 (0.012639)
# CM5-1True: 0.851844 (0.015570)
# CM5-1False: 0.802373 (0.039371)
# ALL: 0.826220 (0.027431)
# **********************************************************
# Statistical tests
# **********************************************************
# ----------------------------------------------------------
# Checking parametric conditions
# ----------------------------------------------------------
# Checking independence
# Ok
# Checking normality using Shapiro-Wilk's test for normality, alpha=0.05
# W: 0.884870, p:0.000000
# The null hypothesis (normality) is rejected
# Checking heteroscedasticity using Levene's test, alpha=0.05
# W: 0.774857, p:0.902435
# The null hypothesis (heteroscedasticity) is accepted
# Conditions for a parametric test are not fulfilled, applying a non-parametric test
# ----------------------------------------------------------
# Working with more than 2 algorithms
# ----------------------------------------------------------
# ----------------------------------------------------------
# Applying Friedman test
# ----------------------------------------------------------
# F-value: 1.456621, p-value: 0.016726717869120944
# Null hypothesis is rejected; hence, models have different performance
# Technique                           Ranking
# --------------------------------  ---------
# COS1(150,150)HoleMakerBounded          59.4
# CMS2(250,250)HoleMakerBounded          59.2
# CM5-1True                              57.8
# CMR1(200,200)                          55.2
# COHS0.05(200,200)                      52.6
# CM1-1False                             51.8
# CMRICAP0.2None                         51.6
# COR1(100,100)                          51.4
# CMS1(150,150)HoleMakerAttention        50.4
# CMS1(150,150)HoleMakerBounded          50.2
# CMS2(150,150)HoleMakerBounded          48.8
# CM31True                               48.2
# COS2(250,250)HoleMakerAttention        47.2
# CM51True                               47
# COS1(150,150)HoleMakerAttention        47
# CM31False                              46.4
# CM11True                               45.6
# CM1-1True                              45.2
# COHS0.15(200,200)                      44.8
# CMR1(100,100)                          44.2
# CMS2(150,150)HoleMakerAttention        44
# COR2(200,200)                          43.2
# COS2(250,250)HoleMakerBounded          43
# CMR1(300,300)                          42.4
# Vanilla                                41.6
# ALL                                    41.2
# COHS0.15(25,25)                        40.6
# COS2(150,150)HoleMakerAttention        40.6
# CMS2(250,250)HoleMakerAttention        40.4
# CM51False                              40.2
# COS2(150,150)HoleMakerBounded          40
# COS1(250,250)HoleMakerAttention        39
# COHS0.15(50,50)                        38.6
# COS1(250,250)HoleMakerBounded          38.6
# CMRmod1(200,200)                       38
# CMRmod2(300,300)                       37.6
# CMR2(200,200)                          37.6
# CMRICAPNone0.2                         36.8
# COHS0.05(25,25)                        36
# COR1(200,200)                          36
# CMRICAP0None                           35.6
# COR2(300,300)                          35.4
# COHS0.05(50,50)                        34.6
# COHS0.25(200,200)                      34.4
# CMRM2(150,150)HoleMakerAttention       34.2
# CMS1(250,250)HoleMakerAttention        34
# CM11False                              33.6
# COR3(100,100)                          33
# COR2(100,100)                          33
# CMRM1(150,150)HoleMakerBounded         32.2
# CMRICAPNone0.4                         32.2
# CMRM1(250,250)HoleMakerAttention       32
# CMRM2(150,150)HoleMakerBounded         31.8
# CMS1(250,250)HoleMakerBounded          30.4
# CMRM1(150,150)HoleMakerAttention       28.8
# CMR2(100,100)                          28.8
# CMR2(300,300)                          28.4
# COR3(300,300)                          27.8
# CM3-1True                              27.6
# CMRICAP0.4None                         27.2
# COR3(200,200)                          26.6
# CMRM1(250,250)HoleMakerBounded         25.8
# CMRmod1(100,100)                       25.4
# COR1(300,300)                          23.8
# CM5-1False                             23.4
# CM3-1False                             22.2
# COHS0.25(25,25)                        21.8
# COHS0.25(50,50)                        20.2
# CMRM2(250,250)HoleMakerAttention       18.4
# CMRM2(250,250)HoleMakerBounded         16
# CMRmod2(100,100)                       14.8
# CMRmod1(300,300)                       14.4
# CMRmod2(200,200)                       13.8
# Winner model: COS1(150,150)HoleMakerBounded
# ----------------------------------------------------------
# Applying Holm p-value adjustment procedure and analysing effect size
# ----------------------------------------------------------
# Comparison                                                            Zvalue      p-value    adjusted p-value
# -----------------------------------------------------------------  ---------  -----------  ------------------
# COS1(150,150)HoleMakerBounded vs CMRmod2(200,200)                  3.39819    0.000678323           0.0488392
# COS1(150,150)HoleMakerBounded vs CMRmod1(300,300)                  3.35348    0.000798019           0.0566593
# COS1(150,150)HoleMakerBounded vs CMRmod2(100,100)                  3.32367    0.000888405           0.0621884
# COS1(150,150)HoleMakerBounded vs CMRM2(250,250)HoleMakerBounded    3.23425    0.00121964            0.0841554
# COS1(150,150)HoleMakerBounded vs CMRM2(250,250)HoleMakerAttention  3.05539    0.00224765            0.15284
# COS1(150,150)HoleMakerBounded vs COHS0.25(50,50)                   2.92125    0.00348625            0.233579
# COS1(150,150)HoleMakerBounded vs COHS0.25(25,25)                   2.80202    0.00507838            0.335173
# COS1(150,150)HoleMakerBounded vs CM3-1False                        2.77221    0.00556769            0.3619
# COS1(150,150)HoleMakerBounded vs CM5-1False                        2.68278    0.0073012             0.467277
# COS1(150,150)HoleMakerBounded vs COR1(300,300)                     2.65298    0.00797855            0.502649
# COS1(150,150)HoleMakerBounded vs CMRmod1(100,100)                  2.53374    0.0112852             0.699683
# COS1(150,150)HoleMakerBounded vs CMRM1(250,250)HoleMakerBounded    2.50393    0.0122821             0.749211
# COS1(150,150)HoleMakerBounded vs COR3(200,200)                     2.44432    0.0145127             0.870765
# COS1(150,150)HoleMakerBounded vs CMRICAP0.4None                    2.3996     0.0164129             0.968362
# COS1(150,150)HoleMakerBounded vs CM3-1True                         2.36979    0.017798              1
# COS1(150,150)HoleMakerBounded vs COR3(300,300)                     2.35489    0.0185282             1
# COS1(150,150)HoleMakerBounded vs CMR2(300,300)                     2.31018    0.0208784             1
# COS1(150,150)HoleMakerBounded vs CMR2(100,100)                     2.28037    0.0225859             1
# COS1(150,150)HoleMakerBounded vs CMRM1(150,150)HoleMakerAttention  2.28037    0.0225859             1
# COS1(150,150)HoleMakerBounded vs CMS1(250,250)HoleMakerBounded     2.16113    0.0306851             1
# COS1(150,150)HoleMakerBounded vs CMRM2(150,150)HoleMakerBounded    2.0568     0.0397053             1
# COS1(150,150)HoleMakerBounded vs CMRM1(250,250)HoleMakerAttention  2.0419     0.0411617             1
# COS1(150,150)HoleMakerBounded vs CMRICAPNone0.4                    2.02699    0.0426631             1
# COS1(150,150)HoleMakerBounded vs CMRM1(150,150)HoleMakerBounded    2.02699    0.0426631             1
# COS1(150,150)HoleMakerBounded vs COR2(100,100)                     1.96738    0.0491399             1
# COS1(150,150)HoleMakerBounded vs COR3(100,100)                     1.96738    0.0491399             1
# COS1(150,150)HoleMakerBounded vs CM11False                         1.92266    0.0545225             1
# COS1(150,150)HoleMakerBounded vs CMS1(250,250)HoleMakerAttention   1.89285    0.0583773             1
# COS1(150,150)HoleMakerBounded vs CMRM2(150,150)HoleMakerAttention  1.87795    0.0603881             1
# COS1(150,150)HoleMakerBounded vs COHS0.25(200,200)                 1.86305    0.0624559             1
# COS1(150,150)HoleMakerBounded vs COHS0.05(50,50)                   1.84814    0.064582              1
# COS1(150,150)HoleMakerBounded vs COR2(300,300)                     1.78852    0.0736916             1
# COS1(150,150)HoleMakerBounded vs CMRICAP0None                      1.77362    0.0761262             1
# COS1(150,150)HoleMakerBounded vs COR1(200,200)                     1.74381    0.0811922             1
# COS1(150,150)HoleMakerBounded vs COHS0.05(25,25)                   1.74381    0.0811922             1
# COS1(150,150)HoleMakerBounded vs CMRICAPNone0.2                    1.68419    0.0921444             1
# COS1(150,150)HoleMakerBounded vs CMR2(200,200)                     1.62458    0.104253              1
# COS1(150,150)HoleMakerBounded vs CMRmod2(300,300)                  1.62458    0.104253              1
# COS1(150,150)HoleMakerBounded vs CMRmod1(200,200)                  1.59477    0.110764              1
# COS1(150,150)HoleMakerBounded vs COS1(250,250)HoleMakerBounded     1.55005    0.121129              1
# COS1(150,150)HoleMakerBounded vs COHS0.15(50,50)                   1.55005    0.121129              1
# COS1(150,150)HoleMakerBounded vs COS1(250,250)HoleMakerAttention   1.52024    0.128449              1
# COS1(150,150)HoleMakerBounded vs COS2(150,150)HoleMakerBounded     1.44572    0.148255              1
# COS1(150,150)HoleMakerBounded vs CM51False                         1.43082    0.152482              1
# COS1(150,150)HoleMakerBounded vs CMS2(250,250)HoleMakerAttention   1.41591    0.156801              1
# COS1(150,150)HoleMakerBounded vs COS2(150,150)HoleMakerAttention   1.40101    0.161211              1
# COS1(150,150)HoleMakerBounded vs COHS0.15(25,25)                   1.40101    0.161211              1
# COS1(150,150)HoleMakerBounded vs ALL                               1.3563     0.175005              1
# COS1(150,150)HoleMakerBounded vs Vanilla                           1.32649    0.184678              1
# COS1(150,150)HoleMakerBounded vs CMR1(300,300)                     1.26687    0.205202              1
# COS1(150,150)HoleMakerBounded vs COS2(250,250)HoleMakerBounded     1.22216    0.221648              1
# COS1(150,150)HoleMakerBounded vs COR2(200,200)                     1.20725    0.227335              1
# COS1(150,150)HoleMakerBounded vs CMS2(150,150)HoleMakerAttention   1.14764    0.251119              1
# COS1(150,150)HoleMakerBounded vs CMR1(100,100)                     1.13273    0.257327              1
# COS1(150,150)HoleMakerBounded vs COHS0.15(200,200)                 1.08802    0.276587              1
# COS1(150,150)HoleMakerBounded vs CM1-1True                         1.05821    0.28996               1
# COS1(150,150)HoleMakerBounded vs CM11True                          1.0284     0.303761              1
# COS1(150,150)HoleMakerBounded vs CM31False                         0.968783   0.332653              1
# COS1(150,150)HoleMakerBounded vs COS1(150,150)HoleMakerAttention   0.92407    0.35545               1
# COS1(150,150)HoleMakerBounded vs CM51True                          0.92407    0.35545               1
# COS1(150,150)HoleMakerBounded vs COS2(250,250)HoleMakerAttention   0.909166   0.363263              1
# COS1(150,150)HoleMakerBounded vs CM31True                          0.834644   0.403918              1
# COS1(150,150)HoleMakerBounded vs CMS2(150,150)HoleMakerBounded     0.789931   0.429568              1
# COS1(150,150)HoleMakerBounded vs CMS1(150,150)HoleMakerBounded     0.685601   0.492965              1
# COS1(150,150)HoleMakerBounded vs CMS1(150,150)HoleMakerAttention   0.670696   0.502414              1
# COS1(150,150)HoleMakerBounded vs COR1(100,100)                     0.596174   0.551059              1
# COS1(150,150)HoleMakerBounded vs CMRICAP0.2None                    0.58127    0.561058              1
# COS1(150,150)HoleMakerBounded vs CM1-1False                        0.566366   0.571145              1
# COS1(150,150)HoleMakerBounded vs COHS0.05(200,200)                 0.506748   0.612331              1
# COS1(150,150)HoleMakerBounded vs CMR1(200,200)                     0.312992   0.754287              1
# COS1(150,150)HoleMakerBounded vs CM5-1True                         0.119235   0.905089              1
# COS1(150,150)HoleMakerBounded vs CMS2(250,250)HoleMakerBounded     0.0149044  0.988108              1
# There is a significant difference between the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMRmod2(200,200) (mean: 0.780006, std: 0.049779) (Cohen's d=1.9408031678003792, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMRmod1(300,300) (mean: 0.786993, std: 0.025543) (Cohen's d=3.3303768266348004, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMRmod2(100,100) (mean: 0.791797, std: 0.034226) (Cohen's d=2.360836538645629, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMRM2(250,250)HoleMakerBounded (mean: 0.783133, std: 0.048427) (Cohen's d=1.912995565828959, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMRM2(250,250)HoleMakerAttention (mean: 0.768397, std: 0.043711) (Cohen's d=2.5331159548199533, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COHS0.25(50,50) (mean: 0.792421, std: 0.042245) (Cohen's d=1.9107485216754512, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COHS0.25(25,25) (mean: 0.750483, std: 0.121156) (Cohen's d=1.1130762812589372, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CM3-1False (mean: 0.798294, std: 0.046487) (Cohen's d=1.5838417895264822, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CM5-1False (mean: 0.802373, std: 0.039371) (Cohen's d=1.7315173994324005, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COR1(300,300) (mean: 0.773209, std: 0.084583) (Cohen's d=1.252483340970307, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMRmod1(100,100) (mean: 0.811443, std: 0.013967) (Cohen's d=3.626350498987761, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMRM1(250,250)HoleMakerBounded (mean: 0.805663, std: 0.030747) (Cohen's d=2.059627944911608, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COR3(200,200) (mean: 0.789099, std: 0.057262) (Cohen's d=1.4931145858343617, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMRICAP0.4None (mean: 0.814543, std: 0.030310) (Cohen's d=1.7286043377769569, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CM3-1True (mean: 0.801477, std: 0.058667) (Cohen's d=1.1934370613702225, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COR3(300,300) (mean: 0.810352, std: 0.023225) (Cohen's d=2.424509315392293, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMR2(300,300) (mean: 0.800869, std: 0.049532) (Cohen's d=1.4239470286406632, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMR2(100,100) (mean: 0.811097, std: 0.028332) (Cohen's d=1.9893678541644386, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMRM1(150,150)HoleMakerAttention (mean: 0.801178, std: 0.041662) (Cohen's d=1.6753006978543705, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMS1(250,250)HoleMakerBounded (mean: 0.816867, std: 0.022683) (Cohen's d=2.1328651086827093, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMRM2(150,150)HoleMakerBounded (mean: 0.809835, std: 0.034993) (Cohen's d=1.675166693047911, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMRM1(250,250)HoleMakerAttention (mean: 0.817611, std: 0.020678) (Cohen's d=2.2722815202907216, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMRICAPNone0.4 (mean: 0.805068, std: 0.042317) (Cohen's d=1.53587581377812, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMRM1(150,150)HoleMakerBounded (mean: 0.815463, std: 0.012725) (Cohen's d=3.5461102269373685, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COR2(100,100) (mean: 0.817134, std: 0.042455) (Cohen's d=1.1774772214045355, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COR3(100,100) (mean: 0.808973, std: 0.060968) (Cohen's d=0.9948782909598634, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CM11False (mean: 0.817852, std: 0.033317) (Cohen's d=1.458803478344347, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMS1(250,250)HoleMakerAttention (mean: 0.817381, std: 0.030368) (Cohen's d=1.6110557062340805, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMRM2(150,150)HoleMakerAttention (mean: 0.823677, std: 0.019673) (Cohen's d=2.01045783278767, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COHS0.25(200,200) (mean: 0.821040, std: 0.027817) (Cohen's d=1.58823853371396, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COHS0.05(50,50) (mean: 0.815578, std: 0.048527) (Cohen's d=1.0741635634116402, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COR2(300,300) (mean: 0.818005, std: 0.021454) (Cohen's d=2.1780898002275237, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMRICAP0None (mean: 0.819364, std: 0.025707) (Cohen's d=1.7868484408697842, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COR1(200,200) (mean: 0.821129, std: 0.012375) (Cohen's d=3.128437318305099, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COHS0.05(25,25) (mean: 0.822032, std: 0.026868) (Cohen's d=1.5951695056299495, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMRICAPNone0.2 (mean: 0.826493, std: 0.024364) (Cohen's d=1.5239669262182107, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMR2(200,200) (mean: 0.819828, std: 0.043649) (Cohen's d=1.069425655172428, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMRmod2(300,300) (mean: 0.821298, std: 0.031336) (Cohen's d=1.4108094183524071, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMRmod1(200,200) (mean: 0.825552, std: 0.024318) (Cohen's d=1.5731978622033251, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COS1(250,250)HoleMakerBounded (mean: 0.824201, std: 0.027790) (Cohen's d=1.4511787143918766, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COHS0.15(50,50) (mean: 0.822200, std: 0.044631) (Cohen's d=0.9803720617837262, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COS1(250,250)HoleMakerAttention (mean: 0.826463, std: 0.040882) (Cohen's d=0.9376942448626252, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COS2(150,150)HoleMakerBounded (mean: 0.822420, std: 0.050554) (Cohen's d=0.8629229766905055, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CM51False (mean: 0.825219, std: 0.012639) (Cohen's d=2.73301034768454, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMS2(250,250)HoleMakerAttention (mean: 0.829441, std: 0.024736) (Cohen's d=1.3593801842073336, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COS2(150,150)HoleMakerAttention (mean: 0.828123, std: 0.025013) (Cohen's d=1.4093075690965056, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COHS0.15(25,25) (mean: 0.828040, std: 0.031015) (Cohen's d=1.1579149046682593, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and ALL (mean: 0.826220, std: 0.027431) (Cohen's d=1.3791924086611946, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and Vanilla (mean: 0.827460, std: 0.035571) (Cohen's d=1.0370481094822348, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMR1(300,300) (mean: 0.832218, std: 0.032848) (Cohen's d=0.9403156391700859, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COS2(250,250)HoleMakerBounded (mean: 0.832013, std: 0.026281) (Cohen's d=1.1674481311406724, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COR2(200,200) (mean: 0.831467, std: 0.007767) (Cohen's d=2.969090658555871, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMS2(150,150)HoleMakerAttention (mean: 0.833316, std: 0.025474) (Cohen's d=1.1394417766553122, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMR1(100,100) (mean: 0.831088, std: 0.026053) (Cohen's d=1.2198374336137738, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COHS0.15(200,200) (mean: 0.833286, std: 0.042220) (Cohen's d=0.7079815275370235, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CM1-1True (mean: 0.834465, std: 0.016173) (Cohen's d=1.6095553679833874, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CM11True (mean: 0.836837, std: 0.026745) (Cohen's d=0.9297976205730902, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CM31False (mean: 0.831131, std: 0.033238) (Cohen's d=0.9701299731581365, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COS1(150,150)HoleMakerAttention (mean: 0.836305, std: 0.027594) (Cohen's d=0.9268243272753806, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CM51True (mean: 0.830115, std: 0.035837) (Cohen's d=0.9381341359970509, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COS2(250,250)HoleMakerAttention (mean: 0.835955, std: 0.026536) (Cohen's d=0.9768697101046775, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CM31True (mean: 0.838461, std: 0.033713) (Cohen's d=0.6892356088106808, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMS2(150,150)HoleMakerBounded (mean: 0.837327, std: 0.044765) (Cohen's d=0.5564576288064299, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMS1(150,150)HoleMakerBounded (mean: 0.836111, std: 0.037246) (Cohen's d=0.7048666211511468, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMS1(150,150)HoleMakerAttention (mean: 0.839674, std: 0.033373) (Cohen's d=0.6511317821793058, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COR1(100,100) (mean: 0.841202, std: 0.013736) (Cohen's d=1.2901412737746747, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMRICAP0.2None (mean: 0.839994, std: 0.022291) (Cohen's d=0.9277426298558435, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CM1-1False (mean: 0.821834, std: 0.092508) (Cohen's d=0.4834580045192328, Medium)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and COHS0.05(200,200) (mean: 0.840124, std: 0.024733) (Cohen's d=0.8384890655146081, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMR1(200,200) (mean: 0.846817, std: 0.022246) (Cohen's d=0.5633569022451635, Large)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CM5-1True (mean: 0.851844, std: 0.015570) (Cohen's d=0.39743757524987133, Medium)
# We can't say that there is a significant difference in the performance of the models: COS1(150,150)HoleMakerBounded (mean: 0.857317, std: 0.007808) and CMS2(250,250)HoleMakerBounded (mean: 0.849804, std: 0.013788) (Cohen's d=0.599745665883039, Large)
# Eta squared: 0.205656 (Large)
