# %%
from StatisticalAnalysis import statisticalComparison
import pandas as pd

# %%
df = pd.read_csv("SSA_testing.csv")
df["Model"] = df["Model"].apply(lambda e: e.replace(" ", ""))
df.to_csv("SSA_testing.csv", index = False)

# %%
statisticalComparison("SSA_testing.csv")
# Out:
# SSA_testing.csv
# ['Vanilla' 'COR1(100,100)' 'COR1(200,200)' 'COR1(300,300)' 'COR2(100,100)'
#  'COR2(200,200)' 'COR2(300,300)' 'COR3(100,100)' 'COR3(200,200)'
#  'COR3(300,300)']
# ==========================================================
# Report
# ==========================================================
# **********************************************************
# Mean and std
# **********************************************************
# Vanilla: 0.833170 (0.032563)
# COR1(100,100): 0.842351 (0.026048)
# COR1(200,200): 0.815087 (0.054387)
# COR1(300,300): 0.830841 (0.024870)
# COR2(100,100): 0.848805 (0.019893)
# COR2(200,200): 0.824135 (0.027384)
# COR2(300,300): 0.799405 (0.069661)
# COR3(100,100): 0.822841 (0.026675)
# COR3(200,200): 0.824245 (0.037656)
# COR3(300,300): 0.829567 (0.046218)
# **********************************************************
# Statistical tests
# **********************************************************
# ----------------------------------------------------------
# Checking parametric conditions
# ----------------------------------------------------------
# Checking independence
# Ok
# Checking normality using Shapiro-Wilk's test for normality, alpha=0.05
# W: 0.889824, p:0.000225
# The null hypothesis (normality) is rejected
# Checking heteroscedasticity using Levene's test, alpha=0.05
# W: 0.485821, p:0.875400
# The null hypothesis (heteroscedasticity) is accepted
# Conditions for a parametric test are not fulfilled, applying a non-parametric test
# ----------------------------------------------------------
# Working with more than 2 algorithms
# ----------------------------------------------------------
# ----------------------------------------------------------
# Applying Friedman test
# ----------------------------------------------------------
# F-value: 0.725086, p-value: 0.6829572453031405
# Null hypothesis is accepted; hence, we can't say that there is a significant difference in the performance of the models
# ----------------------------------------------------------
# Analysing effect size
# ----------------------------------------------------------
# We take the model with the best mean (COR2(100,100), mean: 0.848805) and compare it with the other models:
# Comparing effect size of COR2(100,100) and Vanilla: Cohen's d=0.5182622010636286, Large
# Comparing effect size of COR2(100,100) and COR1(100,100): Cohen's d=0.24905111465239238, Medium
# Comparing effect size of COR2(100,100) and COR1(200,200): Cohen's d=0.7364765930541702, Large
# Comparing effect size of COR2(100,100) and COR1(300,300): Cohen's d=0.7134912845883543, Large
# Comparing effect size of COR2(100,100) and COR2(200,200): Cohen's d=0.9219095088396553, Large
# Comparing effect size of COR2(100,100) and COR2(300,300): Cohen's d=0.8625209591220531, Large
# Comparing effect size of COR2(100,100) and COR3(100,100): Cohen's d=0.9869296676403667, Large
# Comparing effect size of COR2(100,100) and COR3(200,200): Cohen's d=0.7294319858388703, Large
# Comparing effect size of COR2(100,100) and COR3(300,300): Cohen's d=0.4836011501325782, Medium
# Eta squared: 0.098749 (Large)
