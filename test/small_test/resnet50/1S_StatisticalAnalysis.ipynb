# %%
from StatisticalAnalysis import statisticalComparison
import pandas as pd

# %%
df = pd.read_csv("SSA_testing.csv")
df["Model"] = df["Model"].apply(lambda e: e.replace(" ", ""))
df.to_csv("SSA_testing.csv", index = False)

# %%
statisticalComparison("SSA_testing.csv")
# Out:
# SSA_testing.csv
# ['Vanilla' 'COR1(100,100)' 'COR1(200,200)' 'COR1(300,300)' 'COR2(100,100)'
#  'COR2(200,200)' 'COR2(300,300)' 'COR3(100,100)' 'COR3(200,200)'
#  'COR3(300,300)' 'COS1(150,150)HoleMakerBounded'
#  'COS1(150,150)HoleMakerAttention' 'COS1(250,250)HoleMakerBounded'
#  'COS1(250,250)HoleMakerAttention' 'COS2(150,150)HoleMakerBounded'
#  'COS2(150,150)HoleMakerAttention' 'COS2(250,250)HoleMakerBounded'
#  'COS2(250,250)HoleMakerAttention' 'H&S0.05(25,25)' 'H&S0.05(50,50)'
#  'H&S0.05(200,200)' 'H&S0.15(25,25)' 'H&S0.15(50,50)' 'H&S0.15(200,200)'
#  'H&S0.25(25,25)' 'H&S0.25(50,50)' 'H&S0.25(200,200)' 'CMR1(100,100)'
#  'CMR1(200,200)' 'CMR1(300,300)' 'CMR2(100,100)' 'CMR2(200,200)'
#  'CMR2(300,300)' 'CMRmod1(100,100)' 'CMRmod1(200,200)' 'CMRmod1(300,300)'
#  'CMRmod2(100,100)' 'CMRmod2(200,200)' 'CMRmod2(300,300)'
#  'CMS1(150,150)HoleMakerBounded' 'CMS1(150,150)HoleMakerAttention'
#  'CMS1(250,250)HoleMakerBounded' 'CMS1(250,250)HoleMakerAttention'
#  'CMS2(150,150)HoleMakerBounded' 'CMS2(150,150)HoleMakerAttention'
#  'CMS2(250,250)HoleMakerBounded' 'CMS2(250,250)HoleMakerAttention'
#  'RICAP0None' 'RICAP0.2None' 'RICAP0.4None' 'RICAPNone0.2' 'RICAPNone0.4'
#  'ResizeMix1(150,150)HoleMakerBounded'
#  'ResizeMix1(150,150)HoleMakerAttention'
#  'ResizeMix1(250,250)HoleMakerBounded'
#  'ResizeMix1(250,250)HoleMakerAttention'
#  'ResizeMix2(150,150)HoleMakerBounded'
#  'ResizeMix2(150,150)HoleMakerAttention'
#  'ResizeMix2(250,250)HoleMakerBounded'
#  'ResizeMix2(250,250)HoleMakerAttention' 'CM11True' 'CM11False'
#  'CM1-1True' 'CM1-1False' 'CM31True' 'CM31False' 'CM3-1True' 'CM3-1False'
#  'CM51True' 'CM51False' 'CM5-1True' 'CM5-1False' 'SM1-1' 'SM11' 'SM2-1'
#  'SM21' 'SM3-1' 'SM31' 'TM(150,150)HoleMakerRandom'
#  'TM(150,150)HoleMakerBounded' 'TM(150,150)HoleMakerAttention'
#  'TM(250,250)HoleMakerRandom' 'TM(250,250)HoleMakerBounded'
#  'TM(250,250)HoleMakerAttention' 'TM(350,350)HoleMakerRandom'
#  'TM(350,350)HoleMakerBounded' 'TM(350,350)HoleMakerAttention']
# ==========================================================
# Report
# ==========================================================
# **********************************************************
# Mean and std
# **********************************************************
# Vanilla: 0.833170 (0.032563)
# COR1(100,100): 0.842351 (0.026048)
# COR1(200,200): 0.815087 (0.054387)
# COR1(300,300): 0.830841 (0.024870)
# COR2(100,100): 0.848805 (0.019893)
# COR2(200,200): 0.824135 (0.027384)
# COR2(300,300): 0.799405 (0.069661)
# COR3(100,100): 0.822841 (0.026675)
# COR3(200,200): 0.824245 (0.037656)
# COR3(300,300): 0.829567 (0.046218)
# COS1(150,150)HoleMakerBounded: 0.834292 (0.034027)
# COS1(150,150)HoleMakerAttention: 0.827760 (0.021489)
# COS1(250,250)HoleMakerBounded: 0.806482 (0.035667)
# COS1(250,250)HoleMakerAttention: 0.827770 (0.019615)
# COS2(150,150)HoleMakerBounded: 0.840275 (0.029411)
# COS2(150,150)HoleMakerAttention: 0.834319 (0.028860)
# COS2(250,250)HoleMakerBounded: 0.819953 (0.020555)
# COS2(250,250)HoleMakerAttention: 0.835443 (0.060656)
# H&S0.05(25,25): 0.804329 (0.056351)
# H&S0.05(50,50): 0.815301 (0.054589)
# H&S0.05(200,200): 0.831770 (0.031940)
# H&S0.15(25,25): 0.825629 (0.032720)
# H&S0.15(50,50): 0.825437 (0.044031)
# H&S0.15(200,200): 0.806902 (0.062953)
# H&S0.25(25,25): 0.839880 (0.030872)
# H&S0.25(50,50): 0.827386 (0.037983)
# H&S0.25(200,200): 0.829797 (0.036553)
# CMR1(100,100): 0.830927 (0.023699)
# CMR1(200,200): 0.829518 (0.033120)
# CMR1(300,300): 0.850426 (0.012660)
# CMR2(100,100): 0.828183 (0.012984)
# CMR2(200,200): 0.780144 (0.098448)
# CMR2(300,300): 0.816069 (0.061218)
# CMRmod1(100,100): 0.808712 (0.019713)
# CMRmod1(200,200): 0.825689 (0.014714)
# CMRmod1(300,300): 0.825660 (0.027729)
# CMRmod2(100,100): 0.813379 (0.052397)
# CMRmod2(200,200): 0.835220 (0.018196)
# CMRmod2(300,300): 0.842875 (0.024721)
# CMS1(150,150)HoleMakerBounded: 0.832593 (0.021276)
# CMS1(150,150)HoleMakerAttention: 0.852992 (0.020674)
# CMS1(250,250)HoleMakerBounded: 0.846588 (0.015841)
# CMS1(250,250)HoleMakerAttention: 0.820088 (0.042352)
# CMS2(150,150)HoleMakerBounded: 0.829139 (0.025253)
# CMS2(150,150)HoleMakerAttention: 0.844855 (0.028903)
# CMS2(250,250)HoleMakerBounded: 0.829335 (0.021649)
# CMS2(250,250)HoleMakerAttention: 0.839850 (0.014456)
# RICAP0None: 0.813543 (0.029606)
# RICAP0.2None: 0.841485 (0.027305)
# RICAP0.4None: 0.827426 (0.024525)
# RICAPNone0.2: 0.848939 (0.022386)
# RICAPNone0.4: 0.820133 (0.071336)
# ResizeMix1(150,150)HoleMakerBounded: 0.826907 (0.021870)
# ResizeMix1(150,150)HoleMakerAttention: 0.819616 (0.025914)
# ResizeMix1(250,250)HoleMakerBounded: 0.853155 (0.015357)
# ResizeMix1(250,250)HoleMakerAttention: 0.823194 (0.044136)
# ResizeMix2(150,150)HoleMakerBounded: 0.839256 (0.016885)
# ResizeMix2(150,150)HoleMakerAttention: 0.810883 (0.041004)
# ResizeMix2(250,250)HoleMakerBounded: 0.830645 (0.029766)
# ResizeMix2(250,250)HoleMakerAttention: 0.809810 (0.030894)
# CM11True: 0.846133 (0.025217)
# CM11False: 0.818387 (0.024525)
# CM1-1True: 0.847044 (0.018526)
# CM1-1False: 0.795443 (0.062179)
# CM31True: 0.822123 (0.022946)
# CM31False: 0.828182 (0.033034)
# CM3-1True: 0.819460 (0.042784)
# CM3-1False: 0.825306 (0.053999)
# CM51True: 0.840243 (0.045745)
# CM51False: 0.831535 (0.032572)
# CM5-1True: 0.825124 (0.052791)
# CM5-1False: 0.822332 (0.038992)
# SM1-1: 0.850226 (0.010521)
# SM11: 0.835318 (0.048610)
# SM2-1: 0.841138 (0.046217)
# SM21: 0.832384 (0.025123)
# SM3-1: 0.850838 (0.035649)
# SM31: 0.849530 (0.017253)
# TM(150,150)HoleMakerRandom: 0.811547 (0.066226)
# TM(150,150)HoleMakerBounded: 0.839513 (0.023818)
# TM(150,150)HoleMakerAttention: 0.816622 (0.044340)
# TM(250,250)HoleMakerRandom: 0.847912 (0.019637)
# TM(250,250)HoleMakerBounded: 0.847384 (0.022772)
# TM(250,250)HoleMakerAttention: 0.825263 (0.027202)
# TM(350,350)HoleMakerRandom: 0.837585 (0.025523)
# TM(350,350)HoleMakerBounded: 0.855492 (0.016387)
# TM(350,350)HoleMakerAttention: 0.854194 (0.014160)
# **********************************************************
# Statistical tests
# **********************************************************
# ----------------------------------------------------------
# Checking parametric conditions
# ----------------------------------------------------------
# Checking independence
# Ok
# Checking normality using Shapiro-Wilk's test for normality, alpha=0.05
# W: 0.888558, p:0.000000
# The null hypothesis (normality) is rejected
# Checking heteroscedasticity using Levene's test, alpha=0.05
# W: 0.668972, p:0.987027
# The null hypothesis (heteroscedasticity) is accepted
# Conditions for a parametric test are not fulfilled, applying a non-parametric test
# ----------------------------------------------------------
# Working with more than 2 algorithms
# ----------------------------------------------------------
# ----------------------------------------------------------
# Applying Friedman test
# ----------------------------------------------------------
# F-value: 0.858654, p-value: 0.8008634063472453
# Null hypothesis is accepted; hence, we can't say that there is a significant difference in the performance of the models
# ----------------------------------------------------------
# Analysing effect size
# ----------------------------------------------------------
# We take the model with the best mean (TM(350,350)HoleMakerBounded, mean: 0.855492) and compare it with the other models:
# Comparing effect size of TM(350,350)HoleMakerBounded and Vanilla: Cohen's d=0.7745661434763373, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and COR1(100,100): Cohen's d=0.5401441842983492, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and COR1(200,200): Cohen's d=0.899784720717464, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and COR1(300,300): Cohen's d=1.0469774439748252, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and COR2(100,100): Cohen's d=0.3282228762664544, Medium
# Comparing effect size of TM(350,350)HoleMakerBounded and COR2(200,200): Cohen's d=1.2428767403508698, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and COR2(300,300): Cohen's d=0.9913801609041395, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and COR3(100,100): Cohen's d=1.3192394482653096, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and COR3(200,200): Cohen's d=0.9624337703465671, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and COR3(300,300): Cohen's d=0.6687422596750978, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and COS1(150,150)HoleMakerBounded: Cohen's d=0.7100420517518935, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and COS1(150,150)HoleMakerAttention: Cohen's d=1.2980382703035198, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and COS1(250,250)HoleMakerBounded: Cohen's d=1.5794183585858121, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and COS1(250,250)HoleMakerAttention: Cohen's d=1.3719875607917043, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and COS2(150,150)HoleMakerBounded: Cohen's d=0.5717155567372691, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and COS2(150,150)HoleMakerAttention: Cohen's d=0.8069762043272172, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and COS2(250,250)HoleMakerBounded: Cohen's d=1.71010404803542, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and COS2(250,250)HoleMakerAttention: Cohen's d=0.4036299371481292, Medium
# Comparing effect size of TM(350,350)HoleMakerBounded and H&S0.05(25,25): Cohen's d=1.1027738277112427, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and H&S0.05(50,50): Cohen's d=0.8919867313822512, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and H&S0.05(200,200): Cohen's d=0.8358817676069553, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and H&S0.15(25,25): Cohen's d=1.0322354744731712, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and H&S0.15(50,50): Cohen's d=0.8092073324058021, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and H&S0.15(200,200): Cohen's d=0.9448272416763712, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and H&S0.25(25,25): Cohen's d=0.5650272900608094, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and H&S0.25(50,50): Cohen's d=0.8594485070605478, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and H&S0.25(200,200): Cohen's d=0.8113735414215391, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CMR1(100,100): Cohen's d=1.0784454412106041, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CMR1(200,200): Cohen's d=0.8891429592247311, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CMR1(300,300): Cohen's d=0.30944859432551597, Medium
# Comparing effect size of TM(350,350)HoleMakerBounded and CMR2(100,100): Cohen's d=1.6522316549352227, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CMR2(200,200): Cohen's d=0.9549806903147944, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CMR2(300,300): Cohen's d=0.7868792957302939, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CMRmod1(100,100): Cohen's d=2.308310048969218, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CMRmod1(200,200): Cohen's d=1.711706412966634, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CMRmod1(300,300): Cohen's d=1.1715612805145608, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CMRmod2(100,100): Cohen's d=0.9703197502177852, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CMRmod2(200,200): Cohen's d=1.0472136913701149, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CMRmod2(300,300): Cohen's d=0.5381084893969219, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CMS1(150,150)HoleMakerBounded: Cohen's d=1.0785700649392318, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CMS1(150,150)HoleMakerAttention: Cohen's d=0.11989878145486088, Small
# Comparing effect size of TM(350,350)HoleMakerBounded and CMS1(250,250)HoleMakerBounded: Cohen's d=0.4941572505559521, Medium
# Comparing effect size of TM(350,350)HoleMakerBounded and CMS1(250,250)HoleMakerAttention: Cohen's d=0.9861606621056944, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CMS2(150,150)HoleMakerBounded: Cohen's d=1.1073097317474738, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CMS2(150,150)HoleMakerAttention: Cohen's d=0.40497301597047697, Medium
# Comparing effect size of TM(350,350)HoleMakerBounded and CMS2(250,250)HoleMakerBounded: Cohen's d=1.2185810922418252, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CMS2(250,250)HoleMakerAttention: Cohen's d=0.9054834444488861, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and RICAP0None: Cohen's d=1.568082741401288, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and RICAP0.2None: Cohen's d=0.5563840619126101, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and RICAP0.4None: Cohen's d=1.2036030626121372, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and RICAPNone0.2: Cohen's d=0.29880716544955305, Medium
# Comparing effect size of TM(350,350)HoleMakerBounded and RICAPNone0.4: Cohen's d=0.6110610888649549, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and ResizeMix1(150,150)HoleMakerBounded: Cohen's d=1.3231213027814877, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and ResizeMix1(150,150)HoleMakerAttention: Cohen's d=1.480116805094201, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and ResizeMix1(250,250)HoleMakerBounded: Cohen's d=0.13163947990251157, Small
# Comparing effect size of TM(350,350)HoleMakerBounded and ResizeMix1(250,250)HoleMakerAttention: Cohen's d=0.8677703242069997, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and ResizeMix2(150,150)HoleMakerBounded: Cohen's d=0.8728259685284693, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and ResizeMix2(150,150)HoleMakerAttention: Cohen's d=1.2778775185438127, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and ResizeMix2(250,250)HoleMakerBounded: Cohen's d=0.9249877012515759, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and ResizeMix2(250,250)HoleMakerAttention: Cohen's d=1.6523628999634896, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CM11True: Cohen's d=0.3936696999331958, Medium
# Comparing effect size of TM(350,350)HoleMakerBounded and CM11False: Cohen's d=1.5912657016532463, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CM1-1True: Cohen's d=0.4320751924063686, Medium
# Comparing effect size of TM(350,350)HoleMakerBounded and CM1-1False: Cohen's d=1.181257985162354, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CM31True: Cohen's d=1.4969814846474467, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CM31False: Cohen's d=0.9368227159729694, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CM3-1True: Cohen's d=0.9948028998438463, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CM3-1False: Cohen's d=0.6766490380849679, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CM51True: Cohen's d=0.39696238145429963, Medium
# Comparing effect size of TM(350,350)HoleMakerBounded and CM51False: Cohen's d=0.8311081832982244, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CM5-1True: Cohen's d=0.6949535648874728, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and CM5-1False: Cohen's d=0.9917010121476535, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and SM1-1: Cohen's d=0.3420830313824561, Medium
# Comparing effect size of TM(350,350)HoleMakerBounded and SM11: Cohen's d=0.4974709298636335, Medium
# Comparing effect size of TM(350,350)HoleMakerBounded and SM2-1: Cohen's d=0.3702768915384714, Medium
# Comparing effect size of TM(350,350)HoleMakerBounded and SM21: Cohen's d=0.9744750073784517, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and SM3-1: Cohen's d=0.15004947705020344, Small
# Comparing effect size of TM(350,350)HoleMakerBounded and SM31: Cohen's d=0.3169661598747306, Medium
# Comparing effect size of TM(350,350)HoleMakerBounded and TM(150,150)HoleMakerRandom: Cohen's d=0.8147769035012787, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and TM(150,150)HoleMakerBounded: Cohen's d=0.6991346790513645, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and TM(150,150)HoleMakerAttention: Cohen's d=1.0401210866273127, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and TM(250,250)HoleMakerRandom: Cohen's d=0.37489696667687644, Medium
# Comparing effect size of TM(350,350)HoleMakerBounded and TM(250,250)HoleMakerBounded: Cohen's d=0.36558168172063277, Medium
# Comparing effect size of TM(350,350)HoleMakerBounded and TM(250,250)HoleMakerAttention: Cohen's d=1.2041005125803277, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and TM(350,350)HoleMakerRandom: Cohen's d=0.7468223104988952, Large
# Comparing effect size of TM(350,350)HoleMakerBounded and TM(350,350)HoleMakerAttention: Cohen's d=0.07585216053981121, Small
# Eta squared: 0.132054 (Large)
